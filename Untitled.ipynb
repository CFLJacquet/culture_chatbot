# %%
import pandas

p= pandas.read_json("backend/exhibition/data_exhibition.json")
p[p["Photographie"] == 1][["title",'d_end']]
# Out:
#                                                  title       d_end
# 0                                    Paysages français  2018-02-04
# 6                                       Andres Serrano  2018-01-14
# 28                                     Zbigniew Dłubak  2018-04-29
# 30                                       Rues de Paris  2000-01-01
# 31                                 Mémoires des futurs  2018-02-18
# 32                                    Pierre et Gilles  2018-03-10
# 35                                         Dada Africa  2018-02-19
# 40                                     Kacper Kowalski  2000-01-01
# 43                         Ville déserte, Genaro Bardy  2018-01-20
# 47     Exposition Plastic Landscape [in the] Landscape  2018-01-21
# 48                Magali Lambert, Les oiseaux disparus  2018-06-17
# 51          Zbigniew Dlubak, Héritier des avant-gardes  2018-04-29
# 61                               Les Nuits Parisiennes  2018-01-27
# ...
